# %%
import pandas as pd
from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.stats.stattools import durbin_watson
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(mpl.rcParamsDefault)
# mpl.rcParams["text.usetex"] = True
mpl.rcParams["font.family"] = "serif"
mpl.rcParams["font.size"] = "10"

# %%
from utils import (
    adf_test,
    kpss_test,
    grangers_causation_matrix,
    adjust,
    cointegration_test,
    splitter,
    create_plot,
    forecast_accuracy
)

# %% [markdown]
# ### Loading the Dataset

# %%
ts_prices_eth = pd.read_csv("Data/Time_Series/prices/ethereum_19_22.csv",index_col='date',parse_dates=['date'])

# %%
# crypto = 'crypto_bitcoin'
crypto = 'crypto_ethereum'
# crypto = 'crypto_xrp'

# %%
model ='CRYPTOBERT'
df = pd.read_csv(f"Data/Time_Series/{crypto}/{model}_sts_19_22.csv",index_col='posted_on',parse_dates=['posted_on'])

# %%
ts_prices_eth= ts_prices_eth.join(df)

# %%
# Extracting some features from VADER sentiment time series
model ='VADER'
df_ = pd.read_csv(f"Data/Time_Series/{crypto}/{model}_sts_19_22.csv",index_col='posted_on',parse_dates=['posted_on'])
ts_prices_eth= ts_prices_eth.join(df_[['total_stopwords','average_word_length']])

# %%
# Remove Neutral Time Series
for c in ts_prices_eth.columns:
    if 'prop' in c.lower() or 'neutral' in c.lower():
        print(f"Dropping column {c}")
        ts_prices_eth.drop(c,axis=1,inplace=True)
# Out:
# Dropping column neutral_count

# %%
ts_prices_eth = ts_prices_eth[ts_prices_eth.index.year == 2022]
ts_prices_eth.index.year.unique()
# Out:
# Int64Index([2022], dtype='int64', name='date')

# %%
ts_prices_eth.head(5)
# Out:
#               price  positive_count  negative_count  total_posts  total_words  \
# date
# 2022-01-01  3686.40              41               6          150         7882
# 2022-01-02  3780.32              43              13          213        10367
# 2022-01-03  3835.40              59               8          263        13306
# 2022-01-04  3769.40              47               9          242        13281
# 2022-01-05  3794.91              72              12          292        10880
#
#             total_comments  total_stopwords  average_word_length
# date
# 2022-01-01            4182             3286             6.343439
# 2022-01-02            4042             4221             6.353909
# 2022-01-03            3827             5376             6.311037
# 2022-01-04            4250             4489             6.323551
# 2022-01-05            4341             4329             6.227107

# %%
df = ts_prices_eth

# %%
df.isna().sum()
# Out:
# price                  0
# positive_count         0
# negative_count         0
# total_posts            0
# total_words            0
# total_comments         0
# total_stopwords        0
# average_word_length    0
# dtype: int64

# %%
# Checking for Stationarity
for i in range(0,len(df.columns)):
    # fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True)
    # ax1, ax2 = axes.flatten()
    print('Series:', df.columns[i])
    # plot_acf(ts_prices_eth.iloc[1:,i], lags=60, zero=False, alpha=.05, title='Autocorrelation Plot', ax=ax1)
    # plot_pacf(ts_prices_eth.iloc[1:,i], lags=60, zero=False, alpha=.05, title='Partial Autocorrelation Plot', ax=ax2)
    # plt.show()
    adf_test(df.iloc[:,i])
    kpss_test(df.iloc[:,i])
    print("*"*100)
# Out:
# Series: price
# Augmented Dicky Fuller Test
# 	Result: The series is non-stationary
# KPSS Test
# 	Result: The series is non-stationary
# ****************************************************************************************************
# Series: positive_count
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is non-stationary
# ****************************************************************************************************
# Series: negative_count
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is non-stationary
# ****************************************************************************************************
# Series: total_posts
# Augmented Dicky Fuller Test
# 	Result: The series is non-stationary
# KPSS Test
# 	Result: The series is non-stationary
# ****************************************************************************************************
# Series: total_words
# Augmented Dicky Fuller Test
# 	Result: The series is non-stationary
# KPSS Test
# 	Result: The series is non-stationary
# ****************************************************************************************************
# Series: total_comments
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is non-stationary
# ****************************************************************************************************
# Series: total_stopwords
# Augmented Dicky Fuller Test
# 	Result: The series is non-stationary
# KPSS Test
# 	Result: The series is non-stationary
# ****************************************************************************************************
# Series: average_word_length
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is stationary
# ****************************************************************************************************

# %% [markdown]
# Since some of the time series are not stationary, we'll have to take first difference

# %%
df_first_differenced = df.diff().dropna()
# Checking for Stationarity
for i in range(0,len(df_first_differenced.columns)):
    # fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True)
    # ax1, ax2 = axes.flatten()
    print('Series:', df_first_differenced.columns[i])
    # plot_acf(ts_prices_eth.iloc[1:,i], lags=60, zero=False, alpha=.05, title='Autocorrelation Plot', ax=ax1)
    # plot_pacf(ts_prices_eth.iloc[1:,i], lags=60, zero=False, alpha=.05, title='Partial Autocorrelation Plot', ax=ax2)
    # plt.show()
    adf_test(df_first_differenced.iloc[:,i])
    kpss_test(df_first_differenced.iloc[:,i])
    print("*"*100)
# Out:
# Series: price
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is stationary
# ****************************************************************************************************
# Series: positive_count
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is stationary
# ****************************************************************************************************
# Series: negative_count
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is stationary
# ****************************************************************************************************
# Series: total_posts
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is non-stationary
# ****************************************************************************************************
# Series: total_words
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is stationary
# ****************************************************************************************************
# Series: total_comments
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is stationary
# ****************************************************************************************************
# Series: total_stopwords
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is stationary
# ****************************************************************************************************
# Series: average_word_length
# Augmented Dicky Fuller Test
# 	Result: The series is stationary
# KPSS Test
# 	Result: The series is stationary
# ****************************************************************************************************

# %% [markdown]
# ### VAR Model with only 2022 data

# %%
df.columns
# Out:
# Index(['price', 'positive_count', 'negative_count', 'total_posts',
#        'total_words', 'total_comments', 'total_stopwords',
#        'average_word_length'],
#       dtype='object')

# %%
df_first_differenced.head(2)
# Out:
#             price  positive_count  negative_count  total_posts  total_words  \
# date
# 2022-01-02  93.92             2.0             7.0         63.0       2485.0
# 2022-01-03  55.08            16.0            -5.0         50.0       2939.0
#
#             total_comments  total_stopwords  average_word_length
# date
# 2022-01-02          -140.0            935.0             0.010469
# 2022-01-03          -215.0           1155.0            -0.042872

# %%
gc_res = grangers_causation_matrix(df_first_differenced, variables = df_first_differenced.columns, maxlag=40)

# %%
def negative_grey(val):
    color = 'grey' if val < 0.05 else ''
    return 'background-color:' + color  

def negative_bold(val):
    bold = 'bold' if val < 0.05 else ''
    return 'font-weight: %s' % bold

gc_res.style.applymap(negative_grey).applymap(negative_bold)
# Out:
# <style type="text/css">
# #T_aee41_row0_col0, #T_aee41_row0_col1, #T_aee41_row0_col3, #T_aee41_row0_col7, #T_aee41_row1_col0, #T_aee41_row1_col1, #T_aee41_row1_col2, #T_aee41_row1_col7, #T_aee41_row2_col2, #T_aee41_row2_col3, #T_aee41_row2_col4, #T_aee41_row2_col6, #T_aee41_row3_col0, #T_aee41_row3_col2, #T_aee41_row3_col3, #T_aee41_row3_col7, #T_aee41_row4_col0, #T_aee41_row4_col1, #T_aee41_row4_col3, #T_aee41_row4_col4, #T_aee41_row4_col6, #T_aee41_row4_col7, #T_aee41_row5_col1, #T_aee41_row5_col3, #T_aee41_row5_col4, #T_aee41_row5_col5, #T_aee41_row5_col6, #T_aee41_row6_col0, #T_aee41_row6_col1, #T_aee41_row6_col3, #T_aee41_row6_col4, #T_aee41_row6_col6, #T_aee41_row6_col7, #T_aee41_row7_col0, #T_aee41_row7_col4, #T_aee41_row7_col6, #T_aee41_row7_col7 {
#   background-color: ;
#   font-weight: ;
# }
# #T_aee41_row0_col2, #T_aee41_row0_col4, #T_aee41_row0_col5, #T_aee41_row0_col6, #T_aee41_row1_col3, #T_aee41_row1_col4, #T_aee41_row1_col5, #T_aee41_row1_col6, #T_aee41_row2_col0, #T_aee41_row2_col1, #T_aee41_row2_col5, #T_aee41_row2_col7, #T_aee41_row3_col1, #T_aee41_row3_col4, #T_aee41_row3_col5, #T_aee41_row3_col6, #T_aee41_row4_col2, #T_aee41_row4_col5, #T_aee41_row5_col0, #T_aee41_row5_col2, #T_aee41_row5_col7, #T_aee41_row6_col2, #T_aee41_row6_col5, #T_aee41_row7_col1, #T_aee41_row7_col2, #T_aee41_row7_col3, #T_aee41_row7_col5 {
#   background-color: grey;
#   font-weight: bold;
# }
# </style>
# <table id="T_aee41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aee41_level0_col0" class="col_heading level0 col0" >price_x</th>
#       <th id="T_aee41_level0_col1" class="col_heading level0 col1" >positive_count_x</th>
#       <th id="T_aee41_level0_col2" class="col_heading level0 col2" >negative_count_x</th>
#       <th id="T_aee41_level0_col3" class="col_heading level0 col3" >total_posts_x</th>
#       <th id="T_aee41_level0_col4" class="col_heading level0 col4" >total_words_x</th>
#       <th id="T_aee41_level0_col5" class="col_heading level0 col5" >total_comments_x</th>
#       <th id="T_aee41_level0_col6" class="col_heading level0 col6" >total_stopwords_x</th>
#       <th id="T_aee41_level0_col7" class="col_heading level0 col7" >average_word_length_x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aee41_level0_row0" class="row_heading level0 row0" >price_y</th>
#       <td id="T_aee41_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_aee41_row0_col1" class="data row0 col1" >0.452700</td>
#       <td id="T_aee41_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_aee41_row0_col3" class="data row0 col3" >0.087900</td>
#       <td id="T_aee41_row0_col4" class="data row0 col4" >0.028200</td>
#       <td id="T_aee41_row0_col5" class="data row0 col5" >0.000700</td>
#       <td id="T_aee41_row0_col6" class="data row0 col6" >0.021400</td>
#       <td id="T_aee41_row0_col7" class="data row0 col7" >0.434700</td>
#     </tr>
#     <tr>
#       <th id="T_aee41_level0_row1" class="row_heading level0 row1" >positive_count_y</th>
#       <td id="T_aee41_row1_col0" class="data row1 col0" >0.207500</td>
#       <td id="T_aee41_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_aee41_row1_col2" class="data row1 col2" >0.395300</td>
#       <td id="T_aee41_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_aee41_row1_col4" class="data row1 col4" >0.045300</td>
#       <td id="T_aee41_row1_col5" class="data row1 col5" >0.006700</td>
#       <td id="T_aee41_row1_col6" class="data row1 col6" >0.010800</td>
#       <td id="T_aee41_row1_col7" class="data row1 col7" >0.204300</td>
#     </tr>
#     <tr>
#       <th id="T_aee41_level0_row2" class="row_heading level0 row2" >negative_count_y</th>
#       <td id="T_aee41_row2_col0" class="data row2 col0" >0.039000</td>
#       <td id="T_aee41_row2_col1" class="data row2 col1" >0.013100</td>
#       <td id="T_aee41_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_aee41_row2_col3" class="data row2 col3" >0.097400</td>
#       <td id="T_aee41_row2_col4" class="data row2 col4" >0.111600</td>
#       <td id="T_aee41_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_aee41_row2_col6" class="data row2 col6" >0.082300</td>
#       <td id="T_aee41_row2_col7" class="data row2 col7" >0.048400</td>
#     </tr>
#     <tr>
#       <th id="T_aee41_level0_row3" class="row_heading level0 row3" >total_posts_y</th>
#       <td id="T_aee41_row3_col0" class="data row3 col0" >0.121300</td>
#       <td id="T_aee41_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_aee41_row3_col2" class="data row3 col2" >0.341300</td>
#       <td id="T_aee41_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_aee41_row3_col4" class="data row3 col4" >0.033900</td>
#       <td id="T_aee41_row3_col5" class="data row3 col5" >0.002600</td>
#       <td id="T_aee41_row3_col6" class="data row3 col6" >0.003800</td>
#       <td id="T_aee41_row3_col7" class="data row3 col7" >0.254200</td>
#     </tr>
#     <tr>
#       <th id="T_aee41_level0_row4" class="row_heading level0 row4" >total_words_y</th>
#       <td id="T_aee41_row4_col0" class="data row4 col0" >0.290100</td>
#       <td id="T_aee41_row4_col1" class="data row4 col1" >0.208200</td>
#       <td id="T_aee41_row4_col2" class="data row4 col2" >0.001500</td>
#       <td id="T_aee41_row4_col3" class="data row4 col3" >0.076300</td>
#       <td id="T_aee41_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_aee41_row4_col5" class="data row4 col5" >0.005600</td>
#       <td id="T_aee41_row4_col6" class="data row4 col6" >0.092600</td>
#       <td id="T_aee41_row4_col7" class="data row4 col7" >0.097500</td>
#     </tr>
#     <tr>
#       <th id="T_aee41_level0_row5" class="row_heading level0 row5" >total_comments_y</th>
#       <td id="T_aee41_row5_col0" class="data row5 col0" >0.021800</td>
#       <td id="T_aee41_row5_col1" class="data row5 col1" >0.241300</td>
#       <td id="T_aee41_row5_col2" class="data row5 col2" >0.018200</td>
#       <td id="T_aee41_row5_col3" class="data row5 col3" >0.332000</td>
#       <td id="T_aee41_row5_col4" class="data row5 col4" >0.051600</td>
#       <td id="T_aee41_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_aee41_row5_col6" class="data row5 col6" >0.064500</td>
#       <td id="T_aee41_row5_col7" class="data row5 col7" >0.038700</td>
#     </tr>
#     <tr>
#       <th id="T_aee41_level0_row6" class="row_heading level0 row6" >total_stopwords_y</th>
#       <td id="T_aee41_row6_col0" class="data row6 col0" >0.114000</td>
#       <td id="T_aee41_row6_col1" class="data row6 col1" >0.086500</td>
#       <td id="T_aee41_row6_col2" class="data row6 col2" >0.000700</td>
#       <td id="T_aee41_row6_col3" class="data row6 col3" >0.078300</td>
#       <td id="T_aee41_row6_col4" class="data row6 col4" >0.084700</td>
#       <td id="T_aee41_row6_col5" class="data row6 col5" >0.016200</td>
#       <td id="T_aee41_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_aee41_row6_col7" class="data row6 col7" >0.106000</td>
#     </tr>
#     <tr>
#       <th id="T_aee41_level0_row7" class="row_heading level0 row7" >average_word_length_y</th>
#       <td id="T_aee41_row7_col0" class="data row7 col0" >0.067200</td>
#       <td id="T_aee41_row7_col1" class="data row7 col1" >0.006000</td>
#       <td id="T_aee41_row7_col2" class="data row7 col2" >0.000600</td>
#       <td id="T_aee41_row7_col3" class="data row7 col3" >0.000100</td>
#       <td id="T_aee41_row7_col4" class="data row7 col4" >0.143600</td>
#       <td id="T_aee41_row7_col5" class="data row7 col5" >0.000300</td>
#       <td id="T_aee41_row7_col6" class="data row7 col6" >0.067400</td>
#       <td id="T_aee41_row7_col7" class="data row7 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = df.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool),k=1)

# Set up the matplotlib figure
plt.figure(figsize=(10, 6))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, mask=mask, cmap=cmap, vmax=1, center=0, annot=True, fmt=".2f",
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Add title
plt.title('Correlation Heatmap')

# Show the heatmap
plt.show()

# %%
df_first_differenced = df_first_differenced[['price','negative_count','positive_count', 'total_posts',
       'total_words','total_comments']]

# %%
cointegration_test(df_first_differenced)
# Out:
# Name                           ::  Test Stat > C(95%)    =>  Signif
#  ----------------------------------------------------------------------
# price                          ::  692.48    > 83.9383   =>   True
# negative_count                 ::  523.91    > 60.0627   =>   True
# positive_count                 ::  369.71    > 40.1749   =>   True
# total_posts                    ::  245.04    > 24.2761   =>   True
# total_words                    ::  144.2     > 12.3212   =>   True
# total_comments                 ::  51.61     > 4.1296    =>   True

# %%
train_df, test_df = splitter(df_first_differenced)
nobs = len(test_df)

# %%
plt.figure(figsize=(10, 4))

plt.plot(train_df.index, train_df['price'], label='Training', color='blue')
# plt.plot(df_for_validation.index, df_for_validation['price'], label='Validation', color='orange')
plt.plot(test_df.index, test_df['price'], label='Testing', color='green')

# Add title and labels
plt.title('Dataset Split for Training, Validation, and Testing')
plt.xlabel('Date')
plt.ylabel('Price')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
train_df.index[0],train_df.index[-1], len(train_df)
# Out:
# (Timestamp('2022-01-02 00:00:00'), Timestamp('2022-10-19 00:00:00'), 291)

# %%
test_df.index[0],test_df.index[-1],len(test_df)
# Out:
# (Timestamp('2022-10-20 00:00:00'), Timestamp('2022-12-31 00:00:00'), 73)

# %%
model = VAR(train_df)
x = model.select_order(maxlags=30)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model_fitted = model.fit(3)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 24, Jun, 2024
# Time:                     14:40:14
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    51.8603
# Nobs:                     288.000    HQIC:                   50.9915
# Log likelihood:          -9597.03    FPE:                7.82472e+21
# AIC:                      50.4104    Det(Omega_mle):     5.33327e+21
# --------------------------------------------------------------------
# Results for equation price
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -7.260527         5.525670           -1.314           0.189
# L1.price                  0.034620         0.061610            0.562           0.574
# L1.negative_count        -2.133335         1.481807           -1.440           0.150
# L1.positive_count         1.438727         0.696424            2.066           0.039
# L1.total_posts           -0.567211         0.376175           -1.508           0.132
# L1.total_words            0.004105         0.003425            1.199           0.231
# L1.total_comments        -0.019906         0.009413           -2.115           0.034
# L2.price                  0.081956         0.061586            1.331           0.183
# L2.negative_count         1.893854         1.634433            1.159           0.247
# L2.positive_count         1.177935         0.762504            1.545           0.122
# L2.total_posts           -0.274996         0.388094           -0.709           0.479
# L2.total_words           -0.000229         0.003941           -0.058           0.954
# L2.total_comments        -0.024094         0.010970           -2.196           0.028
# L3.price                  0.100209         0.059932            1.672           0.095
# L3.negative_count         0.980671         1.470294            0.667           0.505
# L3.positive_count        -0.334997         0.709208           -0.472           0.637
# L3.total_posts            0.333146         0.364276            0.915           0.360
# L3.total_words            0.001033         0.003395            0.304           0.761
# L3.total_comments        -0.010374         0.009537           -1.088           0.277
# ====================================================================================
#
# Results for equation negative_count
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.064042         0.259002           -0.247           0.805
# L1.price                 -0.000194         0.002888           -0.067           0.946
# L1.negative_count        -0.642525         0.069456           -9.251           0.000
# L1.positive_count         0.033497         0.032643            1.026           0.305
# L1.total_posts           -0.023951         0.017632           -1.358           0.174
# L1.total_words            0.000019         0.000161            0.121           0.904
# L1.total_comments         0.001018         0.000441            2.307           0.021
# L2.price                 -0.003187         0.002887           -1.104           0.270
# L2.negative_count        -0.369152         0.076610           -4.819           0.000
# L2.positive_count        -0.004078         0.035740           -0.114           0.909
# L2.total_posts           -0.018995         0.018191           -1.044           0.296
# L2.total_words           -0.000030         0.000185           -0.165           0.869
# L2.total_comments         0.000915         0.000514            1.780           0.075
# L3.price                  0.001723         0.002809            0.614           0.540
# L3.negative_count        -0.147925         0.068916           -2.146           0.032
# L3.positive_count        -0.023543         0.033242           -0.708           0.479
# L3.total_posts            0.027451         0.017074            1.608           0.108
# L3.total_words            0.000097         0.000159            0.611           0.541
# L3.total_comments         0.000828         0.000447            1.852           0.064
# ====================================================================================
#
# Results for equation positive_count
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.228636         0.762541           -0.300           0.764
# L1.price                 -0.017790         0.008502           -2.092           0.036
# L1.negative_count        -0.492194         0.204489           -2.407           0.016
# L1.positive_count        -0.713769         0.096106           -7.427           0.000
# L1.total_posts            0.050830         0.051912            0.979           0.328
# L1.total_words           -0.000211         0.000473           -0.447           0.655
# L1.total_comments         0.005813         0.001299            4.475           0.000
# L2.price                 -0.002822         0.008499           -0.332           0.740
# L2.negative_count        -0.330987         0.225551           -1.467           0.142
# L2.positive_count        -0.464664         0.105225           -4.416           0.000
# L2.total_posts            0.029762         0.053557            0.556           0.578
# L2.total_words           -0.000131         0.000544           -0.241           0.810
# L2.total_comments         0.002846         0.001514            1.880           0.060
# L3.price                  0.007881         0.008271            0.953           0.341
# L3.negative_count        -0.339019         0.202900           -1.671           0.095
# L3.positive_count        -0.270280         0.097871           -2.762           0.006
# L3.total_posts            0.010242         0.050270            0.204           0.839
# L3.total_words           -0.000194         0.000469           -0.415           0.678
# L3.total_comments         0.001247         0.001316            0.948           0.343
# ====================================================================================
#
# Results for equation total_posts
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -1.050406         1.622647           -0.647           0.517
# L1.price                 -0.006435         0.018092           -0.356           0.722
# L1.negative_count        -1.173029         0.435142           -2.696           0.007
# L1.positive_count        -0.334144         0.204509           -1.634           0.102
# L1.total_posts           -0.407533         0.110466           -3.689           0.000
# L1.total_words            0.000433         0.001006            0.430           0.667
# L1.total_comments         0.012619         0.002764            4.565           0.000
# L2.price                  0.000132         0.018085            0.007           0.994
# L2.negative_count        -0.265443         0.479961           -0.553           0.580
# L2.positive_count        -0.081654         0.223914           -0.365           0.715
# L2.total_posts           -0.330265         0.113966           -2.898           0.004
# L2.total_words           -0.000122         0.001157           -0.105           0.916
# L2.total_comments         0.007526         0.003221            2.336           0.019
# L3.price                  0.000528         0.017599            0.030           0.976
# L3.negative_count        -0.450817         0.431761           -1.044           0.296
# L3.positive_count        -0.267701         0.208263           -1.285           0.199
# L3.total_posts           -0.074734         0.106972           -0.699           0.485
# L3.total_words           -0.000153         0.000997           -0.153           0.878
# L3.total_comments         0.003660         0.002801            1.307           0.191
# ====================================================================================
#
# Results for equation total_words
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                   -70.445913       113.519668           -0.621           0.535
# L1.price                  0.090905         1.265714            0.072           0.943
# L1.negative_count       -68.723940        30.442318           -2.258           0.024
# L1.positive_count       -10.036148        14.307378           -0.701           0.483
# L1.total_posts           10.959000         7.728157            1.418           0.156
# L1.total_words           -0.664655         0.070355           -9.447           0.000
# L1.total_comments         0.307686         0.193385            1.591           0.112
# L2.price                 -0.540592         1.265233           -0.427           0.669
# L2.negative_count        37.174103        33.577878            1.107           0.268
# L2.positive_count        -1.477615        15.664929           -0.094           0.925
# L2.total_posts            4.032693         7.973018            0.506           0.613
# L2.total_words           -0.412100         0.080969           -5.090           0.000
# L2.total_comments         0.039461         0.225358            0.175           0.861
# L3.price                 -0.580439         1.231249           -0.471           0.637
# L3.negative_count        35.808443        30.205804            1.185           0.236
# L3.positive_count        -3.470739        14.570008           -0.238           0.812
# L3.total_posts           -4.427187         7.483704           -0.592           0.554
# L3.total_words           -0.230269         0.069754           -3.301           0.001
# L3.total_comments        -0.133267         0.195938           -0.680           0.496
# ====================================================================================
#
# Results for equation total_comments
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                   -17.398712        46.388190           -0.375           0.708
# L1.price                 -0.321327         0.517216           -0.621           0.534
# L1.negative_count       -25.589309        12.439818           -2.057           0.040
# L1.positive_count         7.814833         5.846505            1.337           0.181
# L1.total_posts           -2.418378         3.158001           -0.766           0.444
# L1.total_words            0.037679         0.028749            1.311           0.190
# L1.total_comments        -0.369609         0.079024           -4.677           0.000
# L2.price                  0.019109         0.517020            0.037           0.971
# L2.negative_count        -9.531648        13.721120           -0.695           0.487
# L2.positive_count         3.796053         6.401249            0.593           0.553
# L2.total_posts           -3.696821         3.258060           -1.135           0.257
# L2.total_words            0.018436         0.033087            0.557           0.577
# L2.total_comments        -0.144173         0.092089           -1.566           0.117
# L3.price                  0.625163         0.503132            1.243           0.214
# L3.negative_count       -10.566689        12.343170           -0.856           0.392
# L3.positive_count        -4.885106         5.953825           -0.820           0.412
# L3.total_posts            1.292330         3.058109            0.423           0.673
# L3.total_words            0.022693         0.028504            0.796           0.426
# L3.total_comments        -0.120453         0.080067           -1.504           0.132
# ====================================================================================
#
# Correlation matrix of residuals
#                      price  negative_count  positive_count  total_posts  total_words  total_comments
# price             1.000000       -0.075141        0.026230     0.100728     0.170880       -0.015412
# negative_count   -0.075141        1.000000        0.199398     0.441335     0.232225        0.389850
# positive_count    0.026230        0.199398        1.000000     0.758722     0.406953        0.529911
# total_posts       0.100728        0.441335        0.758722     1.000000     0.518224        0.583451
# total_words       0.170880        0.232225        0.406953     0.518224     1.000000        0.474999
# total_comments   -0.015412        0.389850        0.529911     0.583451     0.474999        1.000000

# %%
irf = model_fitted.irf(periods=8)

# %%
irf.plot(orth=False, 
        response='price',
        signif=0.10,
        figsize=(4, 12),
        subplot_params={'fontsize': 10})

# %%
fevd = model_fitted.fevd(8)
fevd.plot(figsize=(10, 16))
# plt.xticks(fontsize=5)
# plt.yticks(fontsize=5)
# plt.show()

# %%
# Input data for forecasting
lag_order=model_fitted.k_ar
forecast_input = train_df.values[-lag_order:]
forecast_input
# Out:
# array([[ 3.125e+01, -1.000e+00,  2.000e+00,  9.000e+00,  1.910e+03,
#          1.420e+02],
#        [ 2.650e+01,  1.000e+00,  1.000e+01,  1.300e+01, -1.250e+03,
#         -2.000e+02],
#        [-2.163e+01, -1.000e+00, -5.000e+00, -1.300e+01, -1.290e+02,
#          2.090e+02]])

# %%
forecast_steps = 73
forecast_result = model_fitted.forecast_interval(forecast_input, steps=forecast_steps)

# Extract the forecast and confidence intervals
forecast_values = forecast_result[0]
lower_bound = forecast_result[1]
upper_bound = forecast_result[2]

# Extract the 'price' variable forecast
price_forecast = forecast_values[:, 0]
price_lower = lower_bound[:, 0]
price_upper = upper_bound[:, 0]

# Create a date range for the forecast
# forecast_dates = pd.date_range(start=df.index[-1], periods=forecast_steps+1, closed='right')

# # Plot the results
plt.figure(figsize=(10, 6))
plt.plot(df_first_differenced.index, df_first_differenced['price'], label='Actual BTC Price Difference (USD)',color='red')
plt.plot(test_df.index, price_forecast, label='Forecasted Price', color='blue')
plt.fill_between(test_df.index, price_lower, price_upper, color='blue', alpha=0.3, label='Confidence Interval')

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('BTC Price Forecast with Confidence Intervals')
plt.legend()
plt.grid()
plt.show()

# %%
out = durbin_watson(model_fitted.resid)

for col, val in zip(df_first_differenced.columns, out):
    print(adjust(col), ':', round(val, 2))
# Out:
# price  : 1.96
# negative_count : 2.1
# positive_count : 2.05
# total_posts : 2.05
# total_words : 2.09
# total_comments : 2.02

# %%
fc = model_fitted.forecast(y=forecast_input, steps=nobs)

# %%
forecast = pd.DataFrame(model_fitted.forecast(y= forecast_input, steps=nobs), index = test_df.index,columns = test_df.columns)

# %%
forecast.iloc[0]
# Out:
# price             11.968000
# negative_count     0.755623
# positive_count    -0.329870
# total_posts        2.574531
# total_words       62.330420
# total_comments   -29.733973
# Name: 2022-10-20 00:00:00, dtype: float64

# %%
df_first_differenced.iloc[290]
# Out:
# price             -21.63
# negative_count     -1.00
# positive_count     -5.00
# total_posts       -13.00
# total_words      -129.00
# total_comments    209.00
# Name: 2022-10-19 00:00:00, dtype: float64

# %%
df_first_differenced.columns
# Out:
# Index(['price', 'negative_count', 'positive_count', 'total_posts',
#        'total_words', 'total_comments'],
#       dtype='object')

# %%
row = df.iloc[[0]][['price','positive_count', 'negative_count', 'total_posts', 'total_words',
       'total_comments']]
row
# Out:
#              price  positive_count  negative_count  total_posts  total_words  \
# date
# 2022-01-01  3686.4              41               6          150         7882
#
#             total_comments
# date
# 2022-01-01            4182

# %%
# Invert Transformation
df_result = pd.concat([df_first_differenced.iloc[:291],forecast]) 
df_result = pd.concat([row,df_result]).cumsum()

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(8, 6))
plt.plot(ts_prices_eth['price'].iloc[-nobs:], color = 'red', label = 'Actual eth Price')
plt.plot(df_result['price'].iloc[-nobs:], color = 'blue', label = 'Predicted eth Price')
plt.title('ETH Price Prediction using VAR Model (Sentiment Tool: CryptoBERT)')
plt.xlabel('Time')
plt.xticks(rotation=45)
plt.ylabel('eth Price(USD)')
plt.legend()
plt.show()

# %%
data_predicted = df_result['price'][-nobs:]
data_actual = df['price']
create_plot(data_predicted, data_actual, 'ETH', 'Vader')

# %%
print('Forecast Accuracy of: ETH Price')
# accuracy_prod = 
res = forecast_accuracy(data_predicted.values, data_actual[-nobs:],['ETH_ModelB'])
res
# Out:
# Forecast Accuracy of: ETH Price
#                    MAE       MAPE            MSE        RMSE
# ETH_ModelB  292.605504  22.514163  106102.466196  325.733735
